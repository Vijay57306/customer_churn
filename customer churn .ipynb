# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("done")
import warnings
warnings.filterwarnings("ignore")
# Out:
# done

# %%
df=pd.read_csv(r"C:\Users\Vijay Kumar\Downloads\customer\Telco_customer_churn1.csv")

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1      34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2     34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3     34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4     34.039224, -118.266293  34.039224 -118.266293    Male  ...
# ...                      ...        ...         ...     ...  ...
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female  ...
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male  ...
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female  ...
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female  ...
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# 0     Month-to-month               Yes               Mailed check
# 1     Month-to-month               Yes           Electronic check
# 2     Month-to-month               Yes           Electronic check
# 3     Month-to-month               Yes           Electronic check
# 4     Month-to-month               Yes  Bank transfer (automatic)
# ...              ...               ...                        ...
# 7038        Two year               Yes  Bank transfer (automatic)
# 7039        One year               Yes               Mailed check
# 7040        One year               Yes    Credit card (automatic)
# 7041  Month-to-month               Yes           Electronic check
# 7042        Two year               Yes  Bank transfer (automatic)
#
#       Monthly Charges Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0               53.85        108.15         Yes           1          86  3239
# 1               70.70        151.65         Yes           1          67  2701
# 2               99.65         820.5         Yes           1          86  5372
# 3              104.80       3046.05         Yes           1          84  5003
# 4              103.70        5036.3         Yes           1          89  5340
# ...               ...           ...         ...         ...         ...   ...
# 7038            21.15        1419.4          No           0          45  5306
# 7039            84.80        1990.5          No           0          59  2140
# 7040           103.20        7362.9          No           0          71  5560
# 7041            29.60        346.45          No           0          59  2793
# 7042           105.65        6844.5          No           0          38  5097
#
#                        Churn Reason
# 0      Competitor made better offer
# 1                             Moved
# 2                             Moved
# 3                             Moved
# 4     Competitor had better devices
# ...                             ...
# 7038                            NaN
# 7039                            NaN
# 7040                            NaN
# 7041                            NaN
# 7042                            NaN
#
# [7043 rows x 33 columns]

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value  Churn Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# 25%          35.500000     0.000000    40.000000  3469.000000
# 50%          70.350000     0.000000    61.000000  4527.000000
# 75%          89.850000     1.000000    75.000000  5380.500000
# max         118.750000     1.000000   100.000000  6500.000000

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
df.drop("CustomerID",axis=1,inplace=True)

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Churn Label']=df['Churn Label'].map({'Yes':1,'No':0})

# %%
df
# Out:
#       Count        Country       State          City  Zip Code  \
# 0         1  United States  California   Los Angeles     90003
# 1         1  United States  California   Los Angeles     90005
# 2         1  United States  California   Los Angeles     90006
# 3         1  United States  California   Los Angeles     90010
# 4         1  United States  California   Los Angeles     90015
# ...     ...            ...         ...           ...       ...
# 7038      1  United States  California       Landers     92285
# 7039      1  United States  California      Adelanto     92301
# 7040      1  United States  California         Amboy     92304
# 7041      1  United States  California  Angelus Oaks     92305
# 7042      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1      34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2     34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3     34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4     34.039224, -118.266293  34.039224 -118.266293    Male             No
# ...                      ...        ...         ...     ...            ...
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female             No
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male             No
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female             No
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female             No
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male             No
#
#       ...        Contract Paperless Billing             Payment Method  \
# 0     ...  Month-to-month               Yes               Mailed check
# 1     ...  Month-to-month               Yes           Electronic check
# 2     ...  Month-to-month               Yes           Electronic check
# 3     ...  Month-to-month               Yes           Electronic check
# 4     ...  Month-to-month               Yes  Bank transfer (automatic)
# ...   ...             ...               ...                        ...
# 7038  ...        Two year               Yes  Bank transfer (automatic)
# 7039  ...        One year               Yes               Mailed check
# 7040  ...        One year               Yes    Credit card (automatic)
# 7041  ...  Month-to-month               Yes           Electronic check
# 7042  ...        Two year               Yes  Bank transfer (automatic)
#
#      Monthly Charges Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0              53.85        108.15           1           1          86  3239
# 1              70.70        151.65           1           1          67  2701
# 2              99.65         820.5           1           1          86  5372
# 3             104.80       3046.05           1           1          84  5003
# 4             103.70        5036.3           1           1          89  5340
# ...              ...           ...         ...         ...         ...   ...
# 7038           21.15        1419.4           0           0          45  5306
# 7039           84.80        1990.5           0           0          59  2140
# 7040          103.20        7362.9           0           0          71  5560
# 7041           29.60        346.45           0           0          59  2793
# 7042          105.65        6844.5           0           0          38  5097
#
#                        Churn Reason
# 0      Competitor made better offer
# 1                             Moved
# 2                             Moved
# 3                             Moved
# 4     Competitor had better devices
# ...                             ...
# 7038                            NaN
# 7039                            NaN
# 7040                            NaN
# 7041                            NaN
# 7042                            NaN
#
# [7043 rows x 32 columns]

# %%
df.drop(["Churn Reason"],axis=1,inplace=True)

# %%
#df.drop(['Country','State','City','Zip Code','Lat Long'],axis=1,inplace=True)

# %%
df.drop(["Longitude","Latitude"],axis=1,inplace=True)

# %%
df
# Out:
#       Count        Country       State          City  Zip Code  \
# 0         1  United States  California   Los Angeles     90003
# 1         1  United States  California   Los Angeles     90005
# 2         1  United States  California   Los Angeles     90006
# 3         1  United States  California   Los Angeles     90010
# 4         1  United States  California   Los Angeles     90015
# ...     ...            ...         ...           ...       ...
# 7038      1  United States  California       Landers     92285
# 7039      1  United States  California      Adelanto     92301
# 7040      1  United States  California         Amboy     92304
# 7041      1  United States  California  Angelus Oaks     92305
# 7042      1  United States  California  Apple Valley     92308
#
#                     Lat Long  Gender Senior Citizen Partner Dependents  ...  \
# 0     33.964131, -118.272783    Male             No      No         No  ...
# 1      34.059281, -118.30742  Female             No      No        Yes  ...
# 2     34.048013, -118.293953  Female             No      No        Yes  ...
# 3     34.062125, -118.315709  Female             No     Yes        Yes  ...
# 4     34.039224, -118.266293    Male             No      No        Yes  ...
# ...                      ...     ...            ...     ...        ...  ...
# 7038  34.341737, -116.539416  Female             No      No         No  ...
# 7039  34.667815, -117.536183    Male             No     Yes        Yes  ...
# 7040  34.559882, -115.637164  Female             No     Yes        Yes  ...
# 7041     34.1678, -116.86433  Female             No     Yes        Yes  ...
# 7042  34.424926, -117.184503    Male             No      No         No  ...
#
#          Streaming Movies        Contract Paperless Billing  \
# 0                      No  Month-to-month               Yes
# 1                      No  Month-to-month               Yes
# 2                     Yes  Month-to-month               Yes
# 3                     Yes  Month-to-month               Yes
# 4                     Yes  Month-to-month               Yes
# ...                   ...             ...               ...
# 7038  No internet service        Two year               Yes
# 7039                  Yes        One year               Yes
# 7040                  Yes        One year               Yes
# 7041                   No  Month-to-month               Yes
# 7042                  Yes        Two year               Yes
#
#                  Payment Method Monthly Charges Total Charges Churn Label  \
# 0                  Mailed check           53.85        108.15           1
# 1              Electronic check           70.70        151.65           1
# 2              Electronic check           99.65         820.5           1
# 3              Electronic check          104.80       3046.05           1
# 4     Bank transfer (automatic)          103.70        5036.3           1
# ...                         ...             ...           ...         ...
# 7038  Bank transfer (automatic)           21.15        1419.4           0
# 7039               Mailed check           84.80        1990.5           0
# 7040    Credit card (automatic)          103.20        7362.9           0
# 7041           Electronic check           29.60        346.45           0
# 7042  Bank transfer (automatic)          105.65        6844.5           0
#
#      Churn Value Churn Score  CLTV
# 0              1          86  3239
# 1              1          67  2701
# 2              1          86  5372
# 3              1          84  5003
# 4              1          89  5340
# ...          ...         ...   ...
# 7038           0          45  5306
# 7039           0          59  2140
# 7040           0          71  5560
# 7041           0          59  2793
# 7042           0          38  5097
#
# [7043 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Count', 'Country', 'State', 'City', 'Zip Code', 'Lat Long', 'Gender',
#        'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months',
#        'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label',
#        'Churn Value', 'Churn Score', 'CLTV'],
#       dtype='object')

# %%
df.drop(['Count','Churn Value','Churn Score','CLTV'],axis=1 , inplace=True)

# %%
df
# Out:
#             Country       State          City  Zip Code  \
# 0     United States  California   Los Angeles     90003
# 1     United States  California   Los Angeles     90005
# 2     United States  California   Los Angeles     90006
# 3     United States  California   Los Angeles     90010
# 4     United States  California   Los Angeles     90015
# ...             ...         ...           ...       ...
# 7038  United States  California       Landers     92285
# 7039  United States  California      Adelanto     92301
# 7040  United States  California         Amboy     92304
# 7041  United States  California  Angelus Oaks     92305
# 7042  United States  California  Apple Valley     92308
#
#                     Lat Long  Gender Senior Citizen Partner Dependents  \
# 0     33.964131, -118.272783    Male             No      No         No
# 1      34.059281, -118.30742  Female             No      No        Yes
# 2     34.048013, -118.293953  Female             No      No        Yes
# 3     34.062125, -118.315709  Female             No     Yes        Yes
# 4     34.039224, -118.266293    Male             No      No        Yes
# ...                      ...     ...            ...     ...        ...
# 7038  34.341737, -116.539416  Female             No      No         No
# 7039  34.667815, -117.536183    Male             No     Yes        Yes
# 7040  34.559882, -115.637164  Female             No     Yes        Yes
# 7041     34.1678, -116.86433  Female             No     Yes        Yes
# 7042  34.424926, -117.184503    Male             No      No         No
#
#       Tenure Months  ...    Device Protection         Tech Support  \
# 0                 2  ...                   No                   No
# 1                 2  ...                   No                   No
# 2                 8  ...                  Yes                   No
# 3                28  ...                  Yes                  Yes
# 4                49  ...                  Yes                   No
# ...             ...  ...                  ...                  ...
# 7038             72  ...  No internet service  No internet service
# 7039             24  ...                  Yes                  Yes
# 7040             72  ...                  Yes                   No
# 7041             11  ...                   No                   No
# 7042             66  ...                  Yes                  Yes
#
#              Streaming TV     Streaming Movies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No  Month-to-month
# 2                     Yes                  Yes  Month-to-month
# 3                     Yes                  Yes  Month-to-month
# 4                     Yes                  Yes  Month-to-month
# ...                   ...                  ...             ...
# 7038  No internet service  No internet service        Two year
# 7039                  Yes                  Yes        One year
# 7040                  Yes                  Yes        One year
# 7041                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      Paperless Billing             Payment Method Monthly Charges  \
# 0                  Yes               Mailed check           53.85
# 1                  Yes           Electronic check           70.70
# 2                  Yes           Electronic check           99.65
# 3                  Yes           Electronic check          104.80
# 4                  Yes  Bank transfer (automatic)          103.70
# ...                ...                        ...             ...
# 7038               Yes  Bank transfer (automatic)           21.15
# 7039               Yes               Mailed check           84.80
# 7040               Yes    Credit card (automatic)          103.20
# 7041               Yes           Electronic check           29.60
# 7042               Yes  Bank transfer (automatic)          105.65
#
#      Total Charges Churn Label
# 0           108.15           1
# 1           151.65           1
# 2            820.5           1
# 3          3046.05           1
# 4           5036.3           1
# ...            ...         ...
# 7038        1419.4           0
# 7039        1990.5           0
# 7040        7362.9           0
# 7041        346.45           0
# 7042        6844.5           0
#
# [7043 rows x 25 columns]

# %%
for col in df.columns:
    if df[col].dtype=='object':
        print(col,
    df[col].apply(type).unique())
# Out:
# Country [<class 'str'>]
# State [<class 'str'>]
# City [<class 'str'>]
# Lat Long [<class 'str'>]
# Gender [<class 'str'>]
# Senior Citizen [<class 'str'>]
# Partner [<class 'str'>]
# Dependents [<class 'str'>]
# Phone Service [<class 'str'>]
# Multiple Lines [<class 'str'>]
# Internet Service [<class 'str'>]
# Online Security [<class 'str'>]
# Online Backup [<class 'str'>]
# Device Protection [<class 'str'>]
# Tech Support [<class 'str'>]
# Streaming TV [<class 'str'>]
# Streaming Movies [<class 'str'>]
# Contract [<class 'str'>]
# Paperless Billing [<class 'str'>]
# Payment Method [<class 'str'>]
# Total Charges [<class 'str'>]

# %%
df["Total Charges"].head()
# Out:
# 0     108.15
# 1     151.65
# 2      820.5
# 3    3046.05
# 4     5036.3
# Name: Total Charges, dtype: object

# %%
df["Total Charges"].dtype
# Out:
# dtype('O')

# %%
df["Total Charges"]=pd.to_numeric(df["Total Charges"],errors="coerce")

# %%
df["Total Charges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df["Total Charges"].head(20)
# Out:
# 0      108.15
# 1      151.65
# 2      820.50
# 3     3046.05
# 4     5036.30
# 5      528.35
# 6       39.65
# 7       20.15
# 8     4749.15
# 9       30.20
# 10    1093.10
# 11     316.90
# 12    3549.25
# 13    1105.40
# 14     144.15
# 15    1426.40
# 16     633.30
# 17    1752.55
# 18     857.25
# 19      79.35
# Name: Total Charges, dtype: float64

# %%
df['Total Charges'] = df['Total Charges'].astype(str).str.strip()
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')

# %%
print(df['Total Charges'].dtype)
print(df['Total Charges'].isnull().sum())
# Out:
# float64
# 11

# %%
df['Total Charges'] = df['Total Charges'].fillna(df['Total Charges'].mean(),inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df.columns:
    if df[col].dtype=='object':
        df[col]=le.fit_transform(df[col])

# %%
sns.countplot(x="Churn Label", data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap="coolwarm")
plt.show()

# %%
x=df.drop("Churn Label",axis=1)
y=df["Churn Label"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred=model.predict(X_test)

# %%
Y_pred
# Out:
# array([1, 0, 0, ..., 1, 0, 1], shape=(1409,))

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,Y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7970191625266146

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,Y_pred)
print(cm)
# Out:
# [[893 116]
#  [170 230]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1009
#            1       0.66      0.57      0.62       400
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.79      0.80      0.79      1409

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Churn Label', data=df)
plt.title('Churn Distribution')
plt.show()

# %%
sns.countplot(x='Contract', hue='Churn Label', data=df)
plt.title('Contract vs Churn')
plt.show()

# %%
sns.histplot(df['Monthly Charges'], bins=30, kde=True)
plt.title('Monthly Charges Distribution')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.boxplot(x='Churn Label', y='Tenure Months', data=df)
plt.title('Tenure vs Churn')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=5, random_state=42)
dt.fit(X_train, y_train)

dt_pred = dt.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    random_state=42
)

rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)

# %%
importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf.feature_importances_
}).sort_values('Importance', ascending=False)
print(importance.head(10))
# Out:
#              Feature  Importance
# 9      Tenure Months    0.171688
# 19          Contract    0.131357
# 22   Monthly Charges    0.101227
# 13   Online Security    0.069508
# 3           Zip Code    0.068881
# 4           Lat Long    0.066920
# 2               City    0.064781
# 16      Tech Support    0.057684
# 8         Dependents    0.047484
# 12  Internet Service    0.040790

# %%
input_data = X_test.iloc[[0]]
probability = rf.predict_proba(input_data)[0][1]

if probability > 0.7:
    risk = "High Risk"
elif probability > 0.4:
    risk = "Medium Risk"
else:
    risk = "Low Risk"

print("Risk:", risk)
# Out:
# Risk: Medium Risk

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 st.metric("Churn Probability", f"{probability:.1%}")
#
# NameError: name 'st' is not defined

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\vijay kumar\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\vijay kumar\anaconda3\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\vijay kumar\anaconda3\lib\site-packages (from xgboost) (1.16.3)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


xgb_model = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=4,
    random_state=42
)


xgb_model.fit(X_train, y_train)


xg_pred = xgb_model.predict(X_test)


# Classification Report
print(classification_report(y_test, xg_pred))

# Confusion Matrix
print(confusion_matrix(y_test, xg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1009
#            1       0.68      0.56      0.61       400
#
#     accuracy                           0.80      1409
#    macro avg       0.76      0.73      0.74      1409
# weighted avg       0.79      0.80      0.79      1409
#
# [[903 106]
#  [176 224]]

# %%
from sklearn.metrics import accuracy_score

lr_acc = accuracy_score(y_test, Y_pred)
dt_acc = accuracy_score(y_test, dt_pred)
rf_acc = accuracy_score(y_test, rf_pred)
xgb_acc = accuracy_score(y_test, xg_pred)

print("Logistic Regression:", lr_acc)
print("Decision Tree:", dt_acc)
print("Random Forest:", rf_acc)
print("XGBoost:", xgb_acc)
# Out:
# Logistic Regression: 0.7970191625266146
# Decision Tree: 0.7906316536550745
# Random Forest: 0.7998580553584103
# XGBoost: 0.7998580553584103

# %%
models = ['Logistic Regression',
          'Decision Tree',
          'Random Forest',
         'xgboost']

scores = [
    accuracy_score(y_test, Y_pred),
    accuracy_score(y_test, dt_pred),
    accuracy_score(y_test, rf_pred),
    accuracy_score(y_test,xg_pred)
]

plt.bar(models, scores)
plt.ylabel('Accuracy')
plt.title('Model Comparison')
plt.show()

# %%
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'XGBoost']
accuracies = [lr_acc, dt_acc, rf_acc, xgb_acc]

plt.figure(figsize=(8,5))
sns.barplot(x=models, y=accuracies)

plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.xlabel('Models')

for i, v in enumerate(accuracies):
    plt.text(i, v + 0.005, f'{v:.3f}', ha='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Confusion Matrices
cm_lr = confusion_matrix(y_test, Y_pred)
cm_dt = confusion_matrix(y_test, dt_pred)
cm_rf = confusion_matrix(y_test, rf_pred)
cm_xgb = confusion_matrix(y_test, xg_pred)

# Create 2x2 layout
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Logistic Regression
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues', ax=axes[0,0])
axes[0,0].set_title('Logistic Regression')
axes[0,0].set_xlabel('Predicted')
axes[0,0].set_ylabel('Actual')

# Decision Tree
sns.heatmap(cm_dt, annot=True, fmt='d', cmap='Greens', ax=axes[0,1])
axes[0,1].set_title('Decision Tree')
axes[0,1].set_xlabel('Predicted')
axes[0,1].set_ylabel('Actual')

# Random Forest
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Oranges', ax=axes[1,0])
axes[1,0].set_title('Random Forest')
axes[1,0].set_xlabel('Predicted')
axes[1,0].set_ylabel('Actual')

# XGBoost
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Reds', ax=axes[1,1])
axes[1,1].set_title('XGBoost')
axes[1,1].set_xlabel('Predicted')
axes[1,1].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\vijay kumar\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: keras>=3.12.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\vijay kumar\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vijay kumar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vijay kumar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vijay kumar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vijay kumar\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\vijay kumar\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\vijay kumar\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\vijay kumar\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vijay kumar\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vijay kumar\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# Artificial Neural Network

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Build ANN
ann = Sequential()

# Input + Hidden Layer 1
ann.add(Dense(units=16, activation='relu', input_dim=X_train_scaled.shape[1]))

# Hidden Layer 2
ann.add(Dense(units=8, activation='relu'))

# Output Layer
ann.add(Dense(units=1, activation='sigmoid'))

# Compile Model
ann.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train Model
history = ann.fit(
    X_train_scaled,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# Predictions
y_prob = ann.predict(X_test_scaled)
y_pred_ann = (y_prob > 0.5).astype(int)

# Accuracy
ann_acc = accuracy_score(y_test, y_pred_ann)

print("="*50)
print("ANN Accuracy:", ann_acc)
print("="*50)
# Out:
# Epoch 1/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4460 - loss: 0.7435 - val_accuracy: 0.6699 - val_loss: 0.6778
# Epoch 2/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7255 - loss: 0.6445 - val_accuracy: 0.7595 - val_loss: 0.5888
# Epoch 3/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7646 - loss: 0.5186 - val_accuracy: 0.7844 - val_loss: 0.4470
# Epoch 4/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7892 - loss: 0.4423 - val_accuracy: 0.8048 - val_loss: 0.4164
# Epoch 5/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7937 - loss: 0.4244 - val_accuracy: 0.8119 - val_loss: 0.4046
# Epoch 6/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7992 - loss: 0.4152 - val_accuracy: 0.8146 - val_loss: 0.3982
# Epoch 7/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8016 - loss: 0.4093 - val_accuracy: 0.8154 - val_loss: 0.3942
# Epoch 8/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8061 - loss: 0.4054 - val_accuracy: 0.8137 - val_loss: 0.3931
# Epoch 9/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8103 - loss: 0.4020 - val_accuracy: 0.8163 - val_loss: 0.3894
# Epoch 10/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8118 - loss: 0.3993 - val_accuracy: 0.8181 - val_loss: 0.3882
# Epoch 11/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8143 - loss: 0.3978 - val_accuracy: 0.8208 - val_loss: 0.3893
# Epoch 12/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8134 - loss: 0.3956 - val_accuracy: 0.8208 - val_loss: 0.3872
# Epoch 13/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8189 - loss: 0.3942 - val_accuracy: 0.8163 - val_loss: 0.3871
# Epoch 14/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8165 - loss: 0.3926 - val_accuracy: 0.8208 - val_loss: 0.3877
# Epoch 15/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8178 - loss: 0.3917 - val_accuracy: 0.8181 - val_loss: 0.3883
# Epoch 16/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8187 - loss: 0.3897 - val_accuracy: 0.8208 - val_loss: 0.3869
# Epoch 17/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8221 - loss: 0.3889 - val_accuracy: 0.8190 - val_loss: 0.3868
# Epoch 18/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8221 - loss: 0.3878 - val_accuracy: 0.8190 - val_loss: 0.3879
# Epoch 19/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8209 - loss: 0.3860 - val_accuracy: 0.8199 - val_loss: 0.3871
# Epoch 20/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8243 - loss: 0.3852 - val_accuracy: 0.8225 - val_loss: 0.3894
# Epoch 21/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8245 - loss: 0.3844 - val_accuracy: 0.8172 - val_loss: 0.3893
# Epoch 22/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8254 - loss: 0.3833 - val_accuracy: 0.8154 - val_loss: 0.3894
# Epoch 23/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8238 - loss: 0.3824 - val_accuracy: 0.8146 - val_loss: 0.3901
# Epoch 24/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8245 - loss: 0.3808 - val_accuracy: 0.8172 - val_loss: 0.3899
# Epoch 25/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8252 - loss: 0.3798 - val_accuracy: 0.8190 - val_loss: 0.3934
# Epoch 26/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8272 - loss: 0.3792 - val_accuracy: 0.8225 - val_loss: 0.3925
# Epoch 27/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8285 - loss: 0.3778 - val_accuracy: 0.8172 - val_loss: 0.3912
# Epoch 28/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8285 - loss: 0.3769 - val_accuracy: 0.8190 - val_loss: 0.3924
# Epoch 29/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8278 - loss: 0.3762 - val_accuracy: 0.8119 - val_loss: 0.3955
# Epoch 30/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8256 - loss: 0.3752 - val_accuracy: 0.8208 - val_loss: 0.3931
# Epoch 31/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8278 - loss: 0.3741 - val_accuracy: 0.8172 - val_loss: 0.3940
# Epoch 32/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8276 - loss: 0.3737 - val_accuracy: 0.8154 - val_loss: 0.3949
# Epoch 33/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8292 - loss: 0.3730 - val_accuracy: 0.8190 - val_loss: 0.3939
# Epoch 34/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8300 - loss: 0.3722 - val_accuracy: 0.8181 - val_loss: 0.3947
# Epoch 35/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8285 - loss: 0.3712 - val_accuracy: 0.8137 - val_loss: 0.3955
# Epoch 36/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8300 - loss: 0.3701 - val_accuracy: 0.8146 - val_loss: 0.3977
# Epoch 37/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8298 - loss: 0.3694 - val_accuracy: 0.8172 - val_loss: 0.3981
# Epoch 38/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8298 - loss: 0.3688 - val_accuracy: 0.8163 - val_loss: 0.3977
# Epoch 39/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8305 - loss: 0.3679 - val_accuracy: 0.8154 - val_loss: 0.3975
# Epoch 40/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8327 - loss: 0.3675 - val_accuracy: 0.8137 - val_loss: 0.3976
# Epoch 41/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8343 - loss: 0.3661 - val_accuracy: 0.8119 - val_loss: 0.3983
# Epoch 42/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8314 - loss: 0.3648 - val_accuracy: 0.8146 - val_loss: 0.3991
# Epoch 43/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8331 - loss: 0.3649 - val_accuracy: 0.8083 - val_loss: 0.4001
# Epoch 44/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8340 - loss: 0.3639 - val_accuracy: 0.8092 - val_loss: 0.4028
# Epoch 45/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8363 - loss: 0.3634 - val_accuracy: 0.8137 - val_loss: 0.4004
# Epoch 46/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8325 - loss: 0.3627 - val_accuracy: 0.8146 - val_loss: 0.4014
# Epoch 47/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8338 - loss: 0.3612 - val_accuracy: 0.8101 - val_loss: 0.4033
# Epoch 48/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8349 - loss: 0.3611 - val_accuracy: 0.8101 - val_loss: 0.4023
# Epoch 49/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8363 - loss: 0.3601 - val_accuracy: 0.8101 - val_loss: 0.4032
# Epoch 50/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8378 - loss: 0.3602 - val_accuracy: 0.8110 - val_loss: 0.4035
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ==================================================
# ANN Accuracy: 0.7927608232789212
# ==================================================

# %%
# Classification Report
print(classification_report(y_test, y_pred_ann))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      1009
#            1       0.65      0.58      0.61       400
#
#     accuracy                           0.79      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.79      0.79      0.79      1409

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_ann)

plt.figure(figsize=(6,4))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.title('ANN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Accuracy Curve
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.title('ANN Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Loss Curve
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('ANN Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print(len(y_pred_ann))
# Out:
# 1409

# %%
from sklearn.svm import SVC

# Scale Data
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train SVM
svm = SVC(kernel='rbf', random_state=42)

svm.fit(X_train_scaled, y_train)

# Predictions
svm_pred = svm.predict(X_test_scaled)

# %%
# Accuracy
svm_acc = accuracy_score(y_test, svm_pred)

print("="*50)
print("SVM Accuracy:", svm_acc)
print("="*50)

# Classification Report
print(classification_report(y_test, svm_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, svm_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples')
plt.title('SVM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# ==================================================
# SVM Accuracy: 0.7934705464868701
# ==================================================
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86      1009
#            1       0.68      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.75      0.71      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
from sklearn.metrics import accuracy_score
import pandas as pd

results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "XGBoost",
        "ANN",
        "SVM"
    ],
    "Accuracy": [
        accuracy_score(y_test, Y_pred),
        accuracy_score(y_test, dt_pred),
        accuracy_score(y_test, rf_pred),
        accuracy_score(y_test, xg_pred),
        ann_acc,
        svm_acc
    ]
})

print(results.sort_values("Accuracy", ascending=False))
# Out:
#                  Model  Accuracy
# 2        Random Forest  0.799858
# 3              XGBoost  0.799858
# 0  Logistic Regression  0.797019
# 5                  SVM  0.793471
# 4                  ANN  0.792761
# 1        Decision Tree  0.790632

# %%
import pickle
pickle.dump(rf,open("churn_model.pkl","wb"))

# %%
model=pickle.load(open("churn_model.pkl","rb"))

# %%
model
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=200, random_state=42)

# %%
import pickle 
with open("churn_model.pkl","rb") as file:
    model=pickle.load(file)
